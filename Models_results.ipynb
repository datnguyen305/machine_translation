# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/d/mymomsdatatset/phomt-dataset/dev.json
# /kaggle/input/d/mymomsdatatset/phomt-dataset/train.json
# /kaggle/input/d/mymomsdatatset/phomt-dataset/test.json

# %%
# !rm -rf DS201

# %%
# !git clone https://github.com/datnguyen305/DS201
# Out:
# Cloning into 'DS201'...
# remote: Enumerating objects: 521, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 521 (delta 47), reused 59 (delta 33), pack-reused 415 (from 1)
# Receiving objects: 100% (521/521), 68.72 MiB | 41.39 MiB/s, done.
# Resolving deltas: 100% (200/200), done.

# %%
# %cd DS201/BT4
# Out:
# /kaggle/working/DS201/BT4/DS201/BT4

# %%
# !ls
# Out:
# assignments.ipynb  dataset.py		  models
# baitapdl.ipynb	   LSTM_bahdanau_main.py  preprocess_data.ipynb
# config		   LSTM_Luong_main.py	  vocab.py
# custom_metric	   LSTM_main.py

# %%
# !apt-get update
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
# !apt-get install default-jre
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# default-jre is already the newest version (2:1.11-72build2).
# 0 upgraded, 0 newly installed, 0 to remove and 187 not upgraded.

# %%
# !pip install evaluate nltk
# Out:
# Requirement already satisfied: evaluate in /usr/local/lib/python3.11/dist-packages (0.4.6)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.2)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.4.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from evaluate) (1.26.4)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.2.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.32.5)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.70.18)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.10.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from evaluate) (25.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (3.20.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (22.0.0)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.2.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->evaluate) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->evaluate) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->evaluate) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->evaluate) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->evaluate) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->evaluate) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2025.10.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.22.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets>=2.0.0->evaluate) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->evaluate) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->evaluate) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->evaluate) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->evaluate) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->evaluate) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->evaluate) (2024.2.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1.0.0->datasets>=2.0.0->evaluate) (1.3.1)

# %%
# !python LSTM_Luong_main.py
# Out:
# 2025-12-17 11:20:08.779510: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765970408.801239    3219 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765970408.807708    3219 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /usr/share/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Loading vocab ...
# Creating model ...
# Loading METEOR metric...
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /usr/share/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /usr/share/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Loading dataset ...
# Starting training ...
# Epoch 1 Training: 100%|██████████| 313/313 [01:38<00:00,  3.17it/s, loss=5.7030]
# Evaluating Epoch 1...
#    >>> [DEBUG] METEOR Calculated: 27.19%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [8621, 1812, 2, 0]}
# ratio: 0.9999999999999775
# --- Epoch 01 Complete (Time: 2m 48s) ---
# Training Loss: 6.0527 | Dev Loss: 6.0359
# ⭐️ Dev METEOR: 27.19%
# ⭐️ Dev BLEU-4: 0.00%
#  >>> SAVED: New best model found (BLEU-4: 0.00%)
#
#
# Epoch 2 Training: 100%|██████████| 313/313 [01:37<00:00,  3.20it/s, loss=5.1548]
# Evaluating Epoch 2...
#    >>> [DEBUG] METEOR Calculated: 27.70%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [11192, 2337, 179, 39]}
# ratio: 0.9999999999999775
# --- Epoch 02 Complete (Time: 2m 43s) ---
# Training Loss: 5.4096 | Dev Loss: 5.5197
# ⭐️ Dev METEOR: 27.70%
# ⭐️ Dev BLEU-4: 1.58%
#  >>> SAVED: New best model found (BLEU-4: 1.58%)
#
#
# Epoch 3 Training: 100%|██████████| 313/313 [01:37<00:00,  3.23it/s, loss=4.9218]
# Evaluating Epoch 3...
#    >>> [DEBUG] METEOR Calculated: 25.89%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [11589, 2526, 331, 81]}
# ratio: 0.9999999999999775
# --- Epoch 03 Complete (Time: 2m 42s) ---
# Training Loss: 4.9237 | Dev Loss: 5.3033
# ⭐️ Dev METEOR: 25.89%
# ⭐️ Dev BLEU-4: 2.28%
#  >>> SAVED: New best model found (BLEU-4: 2.28%)
#
#
# Epoch 4 Training: 100%|██████████| 313/313 [01:37<00:00,  3.20it/s, loss=4.6578]
# Evaluating Epoch 4...
#    >>> [DEBUG] METEOR Calculated: 25.69%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12544, 2697, 439, 98]}
# ratio: 0.9999999999999775
# --- Epoch 04 Complete (Time: 2m 43s) ---
# Training Loss: 4.6582 | Dev Loss: 5.1905
# ⭐️ Dev METEOR: 25.69%
# ⭐️ Dev BLEU-4: 2.66%
#  >>> SAVED: New best model found (BLEU-4: 2.66%)
#
#
# Epoch 5 Training: 100%|██████████| 313/313 [01:37<00:00,  3.20it/s, loss=4.5158]
# Evaluating Epoch 5...
#    >>> [DEBUG] METEOR Calculated: 24.19%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12441, 2802, 519, 132]}
# ratio: 0.9999999999999775
# --- Epoch 05 Complete (Time: 2m 45s) ---
# Training Loss: 4.4597 | Dev Loss: 5.1064
# ⭐️ Dev METEOR: 24.19%
# ⭐️ Dev BLEU-4: 3.01%
#  >>> SAVED: New best model found (BLEU-4: 3.01%)
#
#
# Epoch 6 Training: 100%|██████████| 313/313 [01:38<00:00,  3.18it/s, loss=4.2720]
# Evaluating Epoch 6...
#    >>> [DEBUG] METEOR Calculated: 24.19%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12239, 2941, 616, 179]}
# ratio: 0.9999999999999775
# --- Epoch 06 Complete (Time: 2m 45s) ---
# Training Loss: 4.2871 | Dev Loss: 5.0470
# ⭐️ Dev METEOR: 24.19%
# ⭐️ Dev BLEU-4: 3.42%
#  >>> SAVED: New best model found (BLEU-4: 3.42%)
#
#
# Epoch 7 Training: 100%|██████████| 313/313 [01:36<00:00,  3.24it/s, loss=4.3341]
# Evaluating Epoch 7...
#    >>> [DEBUG] METEOR Calculated: 24.22%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12223, 3045, 673, 195]}
# ratio: 0.9999999999999775
# --- Epoch 07 Complete (Time: 2m 44s) ---
# Training Loss: 4.1319 | Dev Loss: 5.0305
# ⭐️ Dev METEOR: 24.22%
# ⭐️ Dev BLEU-4: 3.60%
#  >>> SAVED: New best model found (BLEU-4: 3.60%)
#
#
# Epoch 8 Training: 100%|██████████| 313/313 [01:38<00:00,  3.19it/s, loss=4.2765]
# Evaluating Epoch 8...
#    >>> [DEBUG] METEOR Calculated: 24.81%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12566, 3190, 729, 227]}
# ratio: 0.9999999999999775
# --- Epoch 08 Complete (Time: 2m 44s) ---
# Training Loss: 3.9954 | Dev Loss: 5.0255
# ⭐️ Dev METEOR: 24.81%
# ⭐️ Dev BLEU-4: 3.89%
#  >>> SAVED: New best model found (BLEU-4: 3.89%)
#
#
# Epoch 9 Training: 100%|██████████| 313/313 [01:38<00:00,  3.19it/s, loss=3.7166]
# Evaluating Epoch 9...
#    >>> [DEBUG] METEOR Calculated: 24.36%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12375, 3136, 771, 228]}
# ratio: 0.9999999999999775
# --- Epoch 09 Complete (Time: 2m 45s) ---
# Training Loss: 3.8656 | Dev Loss: 5.0470
# ⭐️ Dev METEOR: 24.36%
# ⭐️ Dev BLEU-4: 3.92%
#  >>> SAVED: New best model found (BLEU-4: 3.92%)
#
#
# Epoch 10 Training: 100%|█████████| 313/313 [01:38<00:00,  3.18it/s, loss=3.6466]
# Evaluating Epoch 10...
#    >>> [DEBUG] METEOR Calculated: 25.74%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12782, 3305, 808, 262]}
# ratio: 0.9999999999999775
# --- Epoch 10 Complete (Time: 2m 45s) ---
# Training Loss: 3.7476 | Dev Loss: 5.0515
# ⭐️ Dev METEOR: 25.74%
# ⭐️ Dev BLEU-4: 4.19%
#  >>> SAVED: New best model found (BLEU-4: 4.19%)
#
#
# Epoch 11 Training: 100%|█████████| 313/313 [01:38<00:00,  3.17it/s, loss=3.5553]
# Evaluating Epoch 11...
#    >>> [DEBUG] METEOR Calculated: 24.55%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12558, 3219, 827, 267]}
# ratio: 0.9999999999999775
# --- Epoch 11 Complete (Time: 2m 45s) ---
# Training Loss: 3.6372 | Dev Loss: 5.0826
# ⭐️ Dev METEOR: 24.55%
# ⭐️ Dev BLEU-4: 4.19%
#  >>> No improvement in BLEU-4. Patience: 1/5
#
#
# Epoch 12 Training: 100%|█████████| 313/313 [01:37<00:00,  3.20it/s, loss=3.6033]
# Evaluating Epoch 12...
#    >>> [DEBUG] METEOR Calculated: 26.77%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12966, 3465, 858, 281]}
# ratio: 0.9999999999999775
# --- Epoch 12 Complete (Time: 2m 43s) ---
# Training Loss: 3.5324 | Dev Loss: 5.0907
# ⭐️ Dev METEOR: 26.77%
# ⭐️ Dev BLEU-4: 4.40%
#  >>> SAVED: New best model found (BLEU-4: 4.40%)
#
#
# Epoch 13 Training: 100%|█████████| 313/313 [01:38<00:00,  3.19it/s, loss=3.5969]
# Evaluating Epoch 13...
#    >>> [DEBUG] METEOR Calculated: 26.06%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12975, 3426, 852, 290]}
# ratio: 0.9999999999999775
# --- Epoch 13 Complete (Time: 2m 43s) ---
# Training Loss: 3.4320 | Dev Loss: 5.1298
# ⭐️ Dev METEOR: 26.06%
# ⭐️ Dev BLEU-4: 4.41%
#  >>> SAVED: New best model found (BLEU-4: 4.41%)
#
#
# Epoch 14 Training: 100%|█████████| 313/313 [01:38<00:00,  3.18it/s, loss=3.3494]
# Evaluating Epoch 14...
#    >>> [DEBUG] METEOR Calculated: 25.95%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13096, 3510, 922, 309]}
# ratio: 0.9999999999999775
# --- Epoch 14 Complete (Time: 2m 44s) ---
# Training Loss: 3.3376 | Dev Loss: 5.1552
# ⭐️ Dev METEOR: 25.95%
# ⭐️ Dev BLEU-4: 4.61%
#  >>> SAVED: New best model found (BLEU-4: 4.61%)
#
#
# Epoch 15 Training: 100%|█████████| 313/313 [01:37<00:00,  3.22it/s, loss=3.2439]
# Evaluating Epoch 15...
#    >>> [DEBUG] METEOR Calculated: 26.47%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13226, 3555, 945, 329]}
# ratio: 0.9999999999999775
# --- Epoch 15 Complete (Time: 2m 43s) ---
# Training Loss: 3.2502 | Dev Loss: 5.1932
# ⭐️ Dev METEOR: 26.47%
# ⭐️ Dev BLEU-4: 4.74%
#  >>> SAVED: New best model found (BLEU-4: 4.74%)
#
#
# Epoch 16 Training: 100%|█████████| 313/313 [01:37<00:00,  3.20it/s, loss=3.1773]
# Evaluating Epoch 16...
#    >>> [DEBUG] METEOR Calculated: 27.06%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13396, 3602, 943, 323]}
# ratio: 0.9999999999999775
# --- Epoch 16 Complete (Time: 2m 44s) ---
# Training Loss: 3.1668 | Dev Loss: 5.2393
# ⭐️ Dev METEOR: 27.06%
# ⭐️ Dev BLEU-4: 4.75%
#  >>> SAVED: New best model found (BLEU-4: 4.75%)
#
#
# Epoch 17 Training: 100%|█████████| 313/313 [01:37<00:00,  3.21it/s, loss=3.0405]
# Evaluating Epoch 17...
#    >>> [DEBUG] METEOR Calculated: 27.06%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13393, 3618, 948, 327]}
# ratio: 0.9999999999999775
# --- Epoch 17 Complete (Time: 2m 43s) ---
# Training Loss: 3.0869 | Dev Loss: 5.2666
# ⭐️ Dev METEOR: 27.06%
# ⭐️ Dev BLEU-4: 4.77%
#  >>> SAVED: New best model found (BLEU-4: 4.77%)
#
#
# Epoch 18 Training: 100%|█████████| 313/313 [01:37<00:00,  3.22it/s, loss=3.0337]
# Evaluating Epoch 18...
#    >>> [DEBUG] METEOR Calculated: 28.33%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13656, 3758, 966, 334]}
# ratio: 0.9999999999999775
# --- Epoch 18 Complete (Time: 2m 42s) ---
# Training Loss: 3.0151 | Dev Loss: 5.2942
# ⭐️ Dev METEOR: 28.33%
# ⭐️ Dev BLEU-4: 4.89%
#  >>> SAVED: New best model found (BLEU-4: 4.89%)
#
#
# Epoch 19 Training: 100%|█████████| 313/313 [01:37<00:00,  3.20it/s, loss=2.8906]
# Evaluating Epoch 19...
#    >>> [DEBUG] METEOR Calculated: 28.44%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13711, 3745, 969, 333]}
# ratio: 0.9999999999999775
# --- Epoch 19 Complete (Time: 2m 44s) ---
# Training Loss: 2.9463 | Dev Loss: 5.3414
# ⭐️ Dev METEOR: 28.44%
# ⭐️ Dev BLEU-4: 4.89%
#  >>> SAVED: New best model found (BLEU-4: 4.89%)
#
#
# Epoch 20 Training: 100%|█████████| 313/313 [01:38<00:00,  3.17it/s, loss=2.7541]
# Evaluating Epoch 20...
#    >>> [DEBUG] METEOR Calculated: 28.40%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13675, 3816, 1010, 364]}
# ratio: 0.9999999999999775
# --- Epoch 20 Complete (Time: 2m 47s) ---
# Training Loss: 2.8832 | Dev Loss: 5.3803
# ⭐️ Dev METEOR: 28.40%
# ⭐️ Dev BLEU-4: 5.07%
#  >>> SAVED: New best model found (BLEU-4: 5.07%)
#
#
# Epoch 21 Training: 100%|█████████| 313/313 [01:37<00:00,  3.20it/s, loss=2.8884]
# Evaluating Epoch 21...
#    >>> [DEBUG] METEOR Calculated: 28.24%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13697, 3808, 1003, 356]}
# ratio: 0.9999999999999775
# --- Epoch 21 Complete (Time: 2m 44s) ---
# Training Loss: 2.8228 | Dev Loss: 5.4138
# ⭐️ Dev METEOR: 28.24%
# ⭐️ Dev BLEU-4: 5.04%
#  >>> No improvement in BLEU-4. Patience: 1/5
#
#
# Epoch 22 Training: 100%|█████████| 313/313 [01:38<00:00,  3.17it/s, loss=2.7184]
# Evaluating Epoch 22...
#    >>> [DEBUG] METEOR Calculated: 28.48%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13730, 3792, 968, 335]}
# ratio: 0.9999999999999775
# --- Epoch 22 Complete (Time: 2m 44s) ---
# Training Loss: 2.7656 | Dev Loss: 5.4456
# ⭐️ Dev METEOR: 28.48%
# ⭐️ Dev BLEU-4: 4.91%
#  >>> No improvement in BLEU-4. Patience: 2/5
#
#
# Epoch 23 Training: 100%|█████████| 313/313 [01:38<00:00,  3.18it/s, loss=2.8500]
# Evaluating Epoch 23...
#    >>> [DEBUG] METEOR Calculated: 28.83%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13846, 3862, 996, 342]}
# ratio: 0.9999999999999775
# --- Epoch 23 Complete (Time: 2m 43s) ---
# Training Loss: 2.7135 | Dev Loss: 5.4792
# ⭐️ Dev METEOR: 28.83%
# ⭐️ Dev BLEU-4: 5.01%
#  >>> No improvement in BLEU-4. Patience: 3/5
#
#
# Epoch 24 Training: 100%|█████████| 313/313 [01:37<00:00,  3.22it/s, loss=2.7489]
# Evaluating Epoch 24...
#    >>> [DEBUG] METEOR Calculated: 28.55%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13827, 3804, 997, 347]}
# ratio: 0.9999999999999775
# --- Epoch 24 Complete (Time: 2m 42s) ---
# Training Loss: 2.6611 | Dev Loss: 5.5260
# ⭐️ Dev METEOR: 28.55%
# ⭐️ Dev BLEU-4: 5.01%
#  >>> No improvement in BLEU-4. Patience: 4/5
#
#
# Epoch 25 Training: 100%|█████████| 313/313 [01:36<00:00,  3.23it/s, loss=2.6985]
# Evaluating Epoch 25...
#    >>> [DEBUG] METEOR Calculated: 28.60%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13847, 3812, 974, 328]}
# ratio: 0.9999999999999775
# --- Epoch 25 Complete (Time: 2m 42s) ---
# Training Loss: 2.6144 | Dev Loss: 5.5555
# ⭐️ Dev METEOR: 28.60%
# ⭐️ Dev BLEU-4: 4.91%
#  >>> No improvement in BLEU-4. Patience: 5/5
#
# *** EARLY STOPPING TRIGGERED (No improve in BLEU-4 for 5 epochs) ***
#
# Evaluating on test set using the BEST saved model ...
# Đã tải mô hình tốt nhất từ checkpoints/best_model.pt
#    >>> [DEBUG] METEOR Calculated: 28.22%
# {'testlen': 49513, 'reflen': 49513, 'guess': [49513, 47513, 45513, 43513], 'correct': [15529, 4343, 1153, 412]}
# ratio: 0.9999999999999799
#
# --- FINAL TEST RESULTS ---
# Test Loss: 5.2843
# METEOR: 28.22%
# BLEU-1: 31.36%
# BLEU-2: 16.93%
# BLEU-3: 8.99%
# BLEU-4: 5.12%
# ROUGE-L: 29.99%

# %%
# !python LSTM_bahdanau_main.py
# Out:
# 2025-12-17 12:30:13.648049: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765974613.669876    4079 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765974613.677164    4079 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /usr/share/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Loading vocab ...
# Creating model ...
# Loading METEOR metric...
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /usr/share/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /usr/share/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Loading dataset ...
# Starting training ...
# Epoch 1 Training: 100%|██████████| 313/313 [02:04<00:00,  2.52it/s, loss=5.5129]
# Evaluating Epoch 1...
#    >>> [DEBUG] METEOR Calculated: 22.72%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [7573, 1285, 2, 0]}
# ratio: 0.9999999999999775
# --- Epoch 01 Complete (Time: 3m 27s) ---
# Training Loss: 6.0665 | Dev Loss: 6.0396
# ⭐️ Dev METEOR: 22.72%
# ⭐️ Dev BLEU-4: 0.00%
#  >>> SAVED: New best model found (BLEU-4: 0.00%)
#
#
# Epoch 2 Training: 100%|██████████| 313/313 [02:04<00:00,  2.52it/s, loss=5.3240]
# Evaluating Epoch 2...
#    >>> [DEBUG] METEOR Calculated: 20.30%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [8663, 1444, 99, 28]}
# ratio: 0.9999999999999775
# --- Epoch 02 Complete (Time: 3m 24s) ---
# Training Loss: 5.5016 | Dev Loss: 5.6229
# ⭐️ Dev METEOR: 20.30%
# ⭐️ Dev BLEU-4: 1.05%
#  >>> SAVED: New best model found (BLEU-4: 1.05%)
#
#
# Epoch 3 Training: 100%|██████████| 313/313 [02:04<00:00,  2.51it/s, loss=4.8005]
# Evaluating Epoch 3...
#    >>> [DEBUG] METEOR Calculated: 25.39%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [11627, 2362, 249, 63]}
# ratio: 0.9999999999999775
# --- Epoch 03 Complete (Time: 3m 25s) ---
# Training Loss: 5.0125 | Dev Loss: 5.3601
# ⭐️ Dev METEOR: 25.39%
# ⭐️ Dev BLEU-4: 1.96%
#  >>> SAVED: New best model found (BLEU-4: 1.96%)
#
#
# Epoch 4 Training: 100%|██████████| 313/313 [02:04<00:00,  2.52it/s, loss=4.7563]
# Evaluating Epoch 4...
#    >>> [DEBUG] METEOR Calculated: 22.38%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [11581, 2420, 372, 96]}
# ratio: 0.9999999999999775
# --- Epoch 04 Complete (Time: 3m 23s) ---
# Training Loss: 4.7316 | Dev Loss: 5.2411
# ⭐️ Dev METEOR: 22.38%
# ⭐️ Dev BLEU-4: 2.42%
#  >>> SAVED: New best model found (BLEU-4: 2.42%)
#
#
# Epoch 5 Training: 100%|██████████| 313/313 [02:03<00:00,  2.53it/s, loss=4.5456]
# Evaluating Epoch 5...
#    >>> [DEBUG] METEOR Calculated: 22.13%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [11269, 2429, 401, 105]}
# ratio: 0.9999999999999775
# --- Epoch 05 Complete (Time: 3m 23s) ---
# Training Loss: 4.5419 | Dev Loss: 5.1873
# ⭐️ Dev METEOR: 22.13%
# ⭐️ Dev BLEU-4: 2.51%
#  >>> SAVED: New best model found (BLEU-4: 2.51%)
#
#
# Epoch 6 Training: 100%|██████████| 313/313 [02:04<00:00,  2.52it/s, loss=4.3566]
# Evaluating Epoch 6...
#    >>> [DEBUG] METEOR Calculated: 22.52%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [10943, 2550, 455, 119]}
# ratio: 0.9999999999999775
# --- Epoch 06 Complete (Time: 3m 24s) ---
# Training Loss: 4.3808 | Dev Loss: 5.1465
# ⭐️ Dev METEOR: 22.52%
# ⭐️ Dev BLEU-4: 2.69%
#  >>> SAVED: New best model found (BLEU-4: 2.69%)
#
#
# Epoch 7 Training: 100%|██████████| 313/313 [02:04<00:00,  2.51it/s, loss=4.4255]
# Evaluating Epoch 7...
#    >>> [DEBUG] METEOR Calculated: 20.70%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [11564, 2473, 529, 151]}
# ratio: 0.9999999999999775
# --- Epoch 07 Complete (Time: 3m 24s) ---
# Training Loss: 4.2373 | Dev Loss: 5.1176
# ⭐️ Dev METEOR: 20.70%
# ⭐️ Dev BLEU-4: 2.98%
#  >>> SAVED: New best model found (BLEU-4: 2.98%)
#
#
# Epoch 8 Training: 100%|██████████| 313/313 [02:04<00:00,  2.52it/s, loss=4.1189]
# Evaluating Epoch 8...
#    >>> [DEBUG] METEOR Calculated: 24.33%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [11981, 2920, 628, 188]}
# ratio: 0.9999999999999775
# --- Epoch 08 Complete (Time: 3m 23s) ---
# Training Loss: 4.1059 | Dev Loss: 5.0853
# ⭐️ Dev METEOR: 24.33%
# ⭐️ Dev BLEU-4: 3.46%
#  >>> SAVED: New best model found (BLEU-4: 3.46%)
#
#
# Epoch 9 Training: 100%|██████████| 313/313 [02:03<00:00,  2.53it/s, loss=3.8869]
# Evaluating Epoch 9...
#    >>> [DEBUG] METEOR Calculated: 22.88%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [11901, 2809, 605, 173]}
# ratio: 0.9999999999999775
# --- Epoch 09 Complete (Time: 3m 22s) ---
# Training Loss: 3.9837 | Dev Loss: 5.1025
# ⭐️ Dev METEOR: 22.88%
# ⭐️ Dev BLEU-4: 3.32%
#  >>> No improvement in BLEU-4. Patience: 1/5
#
#
# Epoch 10 Training: 100%|█████████| 313/313 [02:04<00:00,  2.52it/s, loss=3.5971]
# Evaluating Epoch 10...
#    >>> [DEBUG] METEOR Calculated: 22.68%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [11860, 2836, 646, 191]}
# ratio: 0.9999999999999775
# --- Epoch 10 Complete (Time: 3m 23s) ---
# Training Loss: 3.8686 | Dev Loss: 5.1109
# ⭐️ Dev METEOR: 22.68%
# ⭐️ Dev BLEU-4: 3.46%
#  >>> SAVED: New best model found (BLEU-4: 3.46%)
#
#
# Epoch 11 Training: 100%|█████████| 313/313 [02:04<00:00,  2.52it/s, loss=3.6630]
# Evaluating Epoch 11...
#    >>> [DEBUG] METEOR Calculated: 25.38%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12444, 3139, 714, 212]}
# ratio: 0.9999999999999775
# --- Epoch 11 Complete (Time: 3m 24s) ---
# Training Loss: 3.7587 | Dev Loss: 5.1054
# ⭐️ Dev METEOR: 25.38%
# ⭐️ Dev BLEU-4: 3.78%
#  >>> SAVED: New best model found (BLEU-4: 3.78%)
#
#
# Epoch 12 Training: 100%|█████████| 313/313 [02:04<00:00,  2.52it/s, loss=3.7192]
# Evaluating Epoch 12...
#    >>> [DEBUG] METEOR Calculated: 24.54%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12064, 3051, 706, 228]}
# ratio: 0.9999999999999775
# --- Epoch 12 Complete (Time: 3m 23s) ---
# Training Loss: 3.6547 | Dev Loss: 5.1374
# ⭐️ Dev METEOR: 24.54%
# ⭐️ Dev BLEU-4: 3.78%
#  >>> SAVED: New best model found (BLEU-4: 3.78%)
#
#
# Epoch 13 Training: 100%|█████████| 313/313 [02:05<00:00,  2.50it/s, loss=3.5076]
# Evaluating Epoch 13...
#    >>> [DEBUG] METEOR Calculated: 24.58%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12442, 3071, 708, 227]}
# ratio: 0.9999999999999775
# --- Epoch 13 Complete (Time: 3m 24s) ---
# Training Loss: 3.5576 | Dev Loss: 5.1681
# ⭐️ Dev METEOR: 24.58%
# ⭐️ Dev BLEU-4: 3.82%
#  >>> SAVED: New best model found (BLEU-4: 3.82%)
#
#
# Epoch 14 Training: 100%|█████████| 313/313 [02:04<00:00,  2.51it/s, loss=3.5254]
# Evaluating Epoch 14...
#    >>> [DEBUG] METEOR Calculated: 25.16%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12478, 3103, 730, 226]}
# ratio: 0.9999999999999775
# --- Epoch 14 Complete (Time: 3m 25s) ---
# Training Loss: 3.4643 | Dev Loss: 5.1941
# ⭐️ Dev METEOR: 25.16%
# ⭐️ Dev BLEU-4: 3.85%
#  >>> SAVED: New best model found (BLEU-4: 3.85%)
#
#
# Epoch 15 Training: 100%|█████████| 313/313 [02:04<00:00,  2.52it/s, loss=3.5966]
# Evaluating Epoch 15...
#    >>> [DEBUG] METEOR Calculated: 24.80%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12372, 3184, 783, 259]}
# ratio: 0.9999999999999775
# --- Epoch 15 Complete (Time: 3m 24s) ---
# Training Loss: 3.3725 | Dev Loss: 5.2345
# ⭐️ Dev METEOR: 24.80%
# ⭐️ Dev BLEU-4: 4.08%
#  >>> SAVED: New best model found (BLEU-4: 4.08%)
#
#
# Epoch 16 Training: 100%|█████████| 313/313 [02:04<00:00,  2.52it/s, loss=3.4491]
# Evaluating Epoch 16...
#    >>> [DEBUG] METEOR Calculated: 24.56%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12502, 3131, 771, 243]}
# ratio: 0.9999999999999775
# --- Epoch 16 Complete (Time: 3m 23s) ---
# Training Loss: 3.2908 | Dev Loss: 5.2699
# ⭐️ Dev METEOR: 24.56%
# ⭐️ Dev BLEU-4: 3.99%
#  >>> No improvement in BLEU-4. Patience: 1/5
#
#
# Epoch 17 Training: 100%|█████████| 313/313 [02:05<00:00,  2.50it/s, loss=3.1360]
# Evaluating Epoch 17...
#    >>> [DEBUG] METEOR Calculated: 27.15%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13046, 3417, 831, 270]}
# ratio: 0.9999999999999775
# --- Epoch 17 Complete (Time: 3m 24s) ---
# Training Loss: 3.2112 | Dev Loss: 5.2939
# ⭐️ Dev METEOR: 27.15%
# ⭐️ Dev BLEU-4: 4.31%
#  >>> SAVED: New best model found (BLEU-4: 4.31%)
#
#
# Epoch 18 Training: 100%|█████████| 313/313 [02:05<00:00,  2.50it/s, loss=3.0966]
# Evaluating Epoch 18...
#    >>> [DEBUG] METEOR Calculated: 27.93%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12968, 3439, 795, 268]}
# ratio: 0.9999999999999775
# --- Epoch 18 Complete (Time: 3m 24s) ---
# Training Loss: 3.1360 | Dev Loss: 5.3291
# ⭐️ Dev METEOR: 27.93%
# ⭐️ Dev BLEU-4: 4.26%
#  >>> No improvement in BLEU-4. Patience: 1/5
#
#
# Epoch 19 Training: 100%|█████████| 313/313 [02:05<00:00,  2.50it/s, loss=3.3914]
# Evaluating Epoch 19...
#    >>> [DEBUG] METEOR Calculated: 27.32%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13063, 3423, 819, 284]}
# ratio: 0.9999999999999775
# --- Epoch 19 Complete (Time: 3m 24s) ---
# Training Loss: 3.0666 | Dev Loss: 5.3762
# ⭐️ Dev METEOR: 27.32%
# ⭐️ Dev BLEU-4: 4.35%
#  >>> SAVED: New best model found (BLEU-4: 4.35%)
#
#
# Epoch 20 Training: 100%|█████████| 313/313 [02:03<00:00,  2.54it/s, loss=3.0652]
# Evaluating Epoch 20...
#    >>> [DEBUG] METEOR Calculated: 27.02%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12835, 3422, 842, 284]}
# ratio: 0.9999999999999775
# --- Epoch 20 Complete (Time: 3m 22s) ---
# Training Loss: 2.9981 | Dev Loss: 5.4220
# ⭐️ Dev METEOR: 27.02%
# ⭐️ Dev BLEU-4: 4.36%
#  >>> SAVED: New best model found (BLEU-4: 4.36%)
#
#
# Epoch 21 Training: 100%|█████████| 313/313 [02:04<00:00,  2.52it/s, loss=2.8182]
# Evaluating Epoch 21...
#    >>> [DEBUG] METEOR Calculated: 28.01%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13174, 3571, 857, 291]}
# ratio: 0.9999999999999775
# --- Epoch 21 Complete (Time: 3m 23s) ---
# Training Loss: 2.9389 | Dev Loss: 5.4601
# ⭐️ Dev METEOR: 28.01%
# ⭐️ Dev BLEU-4: 4.49%
#  >>> SAVED: New best model found (BLEU-4: 4.49%)
#
#
# Epoch 22 Training: 100%|█████████| 313/313 [02:04<00:00,  2.51it/s, loss=3.0048]
# Evaluating Epoch 22...
#    >>> [DEBUG] METEOR Calculated: 27.21%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13056, 3499, 856, 285]}
# ratio: 0.9999999999999775
# --- Epoch 22 Complete (Time: 3m 24s) ---
# Training Loss: 2.8795 | Dev Loss: 5.4929
# ⭐️ Dev METEOR: 27.21%
# ⭐️ Dev BLEU-4: 4.43%
#  >>> No improvement in BLEU-4. Patience: 1/5
#
#
# Epoch 23 Training: 100%|█████████| 313/313 [02:05<00:00,  2.50it/s, loss=2.8734]
# Evaluating Epoch 23...
#    >>> [DEBUG] METEOR Calculated: 28.39%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13238, 3591, 874, 293]}
# ratio: 0.9999999999999775
# --- Epoch 23 Complete (Time: 3m 24s) ---
# Training Loss: 2.8236 | Dev Loss: 5.5241
# ⭐️ Dev METEOR: 28.39%
# ⭐️ Dev BLEU-4: 4.53%
#  >>> SAVED: New best model found (BLEU-4: 4.53%)
#
#
# Epoch 24 Training: 100%|█████████| 313/313 [02:04<00:00,  2.52it/s, loss=2.7324]
# Evaluating Epoch 24...
#    >>> [DEBUG] METEOR Calculated: 28.08%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13346, 3577, 879, 304]}
# ratio: 0.9999999999999775
# --- Epoch 24 Complete (Time: 3m 23s) ---
# Training Loss: 2.7710 | Dev Loss: 5.5573
# ⭐️ Dev METEOR: 28.08%
# ⭐️ Dev BLEU-4: 4.58%
#  >>> SAVED: New best model found (BLEU-4: 4.58%)
#
#
# Epoch 25 Training: 100%|█████████| 313/313 [02:04<00:00,  2.52it/s, loss=2.7677]
# Evaluating Epoch 25...
#    >>> [DEBUG] METEOR Calculated: 28.39%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13289, 3567, 875, 303]}
# ratio: 0.9999999999999775
# --- Epoch 25 Complete (Time: 3m 23s) ---
# Training Loss: 2.7214 | Dev Loss: 5.5981
# ⭐️ Dev METEOR: 28.39%
# ⭐️ Dev BLEU-4: 4.56%
#  >>> No improvement in BLEU-4. Patience: 1/5
#
#
# Epoch 26 Training: 100%|█████████| 313/313 [02:05<00:00,  2.50it/s, loss=2.6499]
# Evaluating Epoch 26...
#    >>> [DEBUG] METEOR Calculated: 30.50%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13695, 3824, 876, 291]}
# ratio: 0.9999999999999775
# --- Epoch 26 Complete (Time: 3m 23s) ---
# Training Loss: 2.6713 | Dev Loss: 5.6289
# ⭐️ Dev METEOR: 30.50%
# ⭐️ Dev BLEU-4: 4.63%
#  >>> SAVED: New best model found (BLEU-4: 4.63%)
#
#
# Epoch 27 Training: 100%|█████████| 313/313 [02:03<00:00,  2.53it/s, loss=2.8496]
# Evaluating Epoch 27...
#    >>> [DEBUG] METEOR Calculated: 28.52%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13372, 3642, 891, 303]}
# ratio: 0.9999999999999775
# --- Epoch 27 Complete (Time: 3m 22s) ---
# Training Loss: 2.6302 | Dev Loss: 5.6761
# ⭐️ Dev METEOR: 28.52%
# ⭐️ Dev BLEU-4: 4.62%
#  >>> No improvement in BLEU-4. Patience: 1/5
#
#
# Epoch 28 Training: 100%|█████████| 313/313 [02:04<00:00,  2.52it/s, loss=2.6627]
# Evaluating Epoch 28...
#    >>> [DEBUG] METEOR Calculated: 28.47%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13312, 3637, 888, 301]}
# ratio: 0.9999999999999775
# --- Epoch 28 Complete (Time: 3m 24s) ---
# Training Loss: 2.5850 | Dev Loss: 5.7122
# ⭐️ Dev METEOR: 28.47%
# ⭐️ Dev BLEU-4: 4.60%
#  >>> No improvement in BLEU-4. Patience: 2/5
#
#
# Epoch 29 Training: 100%|█████████| 313/313 [02:03<00:00,  2.52it/s, loss=2.5605]
# Evaluating Epoch 29...
#    >>> [DEBUG] METEOR Calculated: 28.94%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13543, 3675, 899, 316]}
# ratio: 0.9999999999999775
# --- Epoch 29 Complete (Time: 3m 22s) ---
# Training Loss: 2.5431 | Dev Loss: 5.7509
# ⭐️ Dev METEOR: 28.94%
# ⭐️ Dev BLEU-4: 4.70%
#  >>> SAVED: New best model found (BLEU-4: 4.70%)
#
#
# Epoch 30 Training: 100%|█████████| 313/313 [02:04<00:00,  2.51it/s, loss=2.5249]
# Evaluating Epoch 30...
#    >>> [DEBUG] METEOR Calculated: 29.28%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13640, 3678, 887, 303]}
# ratio: 0.9999999999999775
# --- Epoch 30 Complete (Time: 3m 23s) ---
# Training Loss: 2.5046 | Dev Loss: 5.7807
# ⭐️ Dev METEOR: 29.28%
# ⭐️ Dev BLEU-4: 4.65%
#  >>> No improvement in BLEU-4. Patience: 1/5
#
#
# Epoch 31 Training: 100%|█████████| 313/313 [02:04<00:00,  2.52it/s, loss=2.5743]
# Evaluating Epoch 31...
#    >>> [DEBUG] METEOR Calculated: 29.34%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13645, 3726, 907, 302]}
# ratio: 0.9999999999999775
# --- Epoch 31 Complete (Time: 3m 22s) ---
# Training Loss: 2.4647 | Dev Loss: 5.8108
# ⭐️ Dev METEOR: 29.34%
# ⭐️ Dev BLEU-4: 4.68%
#  >>> No improvement in BLEU-4. Patience: 2/5
#
#
# Epoch 32 Training: 100%|█████████| 313/313 [02:03<00:00,  2.53it/s, loss=2.4416]
# Evaluating Epoch 32...
#    >>> [DEBUG] METEOR Calculated: 29.90%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13677, 3769, 913, 309]}
# ratio: 0.9999999999999775
# --- Epoch 32 Complete (Time: 3m 22s) ---
# Training Loss: 2.4308 | Dev Loss: 5.8676
# ⭐️ Dev METEOR: 29.90%
# ⭐️ Dev BLEU-4: 4.73%
#  >>> SAVED: New best model found (BLEU-4: 4.73%)
#
#
# Epoch 33 Training: 100%|█████████| 313/313 [02:05<00:00,  2.50it/s, loss=2.3600]
# Evaluating Epoch 33...
#    >>> [DEBUG] METEOR Calculated: 29.22%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13621, 3673, 904, 297]}
# ratio: 0.9999999999999775
# --- Epoch 33 Complete (Time: 3m 24s) ---
# Training Loss: 2.3944 | Dev Loss: 5.9030
# ⭐️ Dev METEOR: 29.22%
# ⭐️ Dev BLEU-4: 4.64%
#  >>> No improvement in BLEU-4. Patience: 1/5
#
#
# Epoch 34 Training: 100%|█████████| 313/313 [02:04<00:00,  2.50it/s, loss=2.4618]
# Evaluating Epoch 34...
#    >>> [DEBUG] METEOR Calculated: 30.56%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13946, 3846, 930, 314]}
# ratio: 0.9999999999999775
# --- Epoch 34 Complete (Time: 3m 24s) ---
# Training Loss: 2.3618 | Dev Loss: 5.9287
# ⭐️ Dev METEOR: 30.56%
# ⭐️ Dev BLEU-4: 4.82%
#  >>> SAVED: New best model found (BLEU-4: 4.82%)
#
#
# Epoch 35 Training: 100%|█████████| 313/313 [02:04<00:00,  2.51it/s, loss=2.3065]
# Evaluating Epoch 35...
#    >>> [DEBUG] METEOR Calculated: 29.62%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13729, 3780, 898, 291]}
# ratio: 0.9999999999999775
# --- Epoch 35 Complete (Time: 3m 23s) ---
# Training Loss: 2.3290 | Dev Loss: 5.9764
# ⭐️ Dev METEOR: 29.62%
# ⭐️ Dev BLEU-4: 4.65%
#  >>> No improvement in BLEU-4. Patience: 1/5
#
#
# Epoch 36 Training: 100%|█████████| 313/313 [02:04<00:00,  2.52it/s, loss=2.1913]
# Evaluating Epoch 36...
#    >>> [DEBUG] METEOR Calculated: 29.05%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13613, 3650, 908, 308]}
# ratio: 0.9999999999999775
# --- Epoch 36 Complete (Time: 3m 23s) ---
# Training Loss: 2.2948 | Dev Loss: 6.0087
# ⭐️ Dev METEOR: 29.05%
# ⭐️ Dev BLEU-4: 4.68%
#  >>> No improvement in BLEU-4. Patience: 2/5
#
#
# Epoch 37 Training: 100%|█████████| 313/313 [02:04<00:00,  2.51it/s, loss=2.3859]
# Evaluating Epoch 37...
#    >>> [DEBUG] METEOR Calculated: 29.30%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13602, 3665, 883, 295]}
# ratio: 0.9999999999999775
# --- Epoch 37 Complete (Time: 3m 24s) ---
# Training Loss: 2.2662 | Dev Loss: 6.0415
# ⭐️ Dev METEOR: 29.30%
# ⭐️ Dev BLEU-4: 4.60%
#  >>> No improvement in BLEU-4. Patience: 3/5
#
#
# Epoch 38 Training: 100%|█████████| 313/313 [02:04<00:00,  2.51it/s, loss=2.3427]
# Evaluating Epoch 38...
#    >>> [DEBUG] METEOR Calculated: 30.24%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13871, 3781, 908, 303]}
# ratio: 0.9999999999999775
# --- Epoch 38 Complete (Time: 3m 24s) ---
# Training Loss: 2.2369 | Dev Loss: 6.0640
# ⭐️ Dev METEOR: 30.24%
# ⭐️ Dev BLEU-4: 4.72%
#  >>> No improvement in BLEU-4. Patience: 4/5
#
#
# Epoch 39 Training: 100%|█████████| 313/313 [02:04<00:00,  2.52it/s, loss=2.2884]
# Evaluating Epoch 39...
#    >>> [DEBUG] METEOR Calculated: 30.29%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13811, 3786, 897, 292]}
# ratio: 0.9999999999999775
# --- Epoch 39 Complete (Time: 3m 23s) ---
# Training Loss: 2.2081 | Dev Loss: 6.0992
# ⭐️ Dev METEOR: 30.29%
# ⭐️ Dev BLEU-4: 4.66%
#  >>> No improvement in BLEU-4. Patience: 5/5
#
# *** EARLY STOPPING TRIGGERED (No improve in BLEU-4 for 5 epochs) ***
#
# Evaluating on test set using the BEST saved model ...
# Đã tải mô hình tốt nhất từ checkpoints/best_model.pt
#    >>> [DEBUG] METEOR Calculated: 30.03%
# {'testlen': 49513, 'reflen': 49513, 'guess': [49513, 47513, 45513, 43513], 'correct': [15657, 4346, 1063, 381]}
# ratio: 0.9999999999999799
#
# --- FINAL TEST RESULTS ---
# Test Loss: 5.8145
# METEOR: 30.03%
# BLEU-1: 31.62%
# BLEU-2: 17.01%
# BLEU-3: 8.77%
# BLEU-4: 4.93%
# ROUGE-L: 30.22%

# %%
# !python LSTM_main.py
# Out:
# 2025-12-17 14:44:38.373544: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765982678.395185    5403 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765982678.402002    5403 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /usr/share/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Loading vocab ...
# Creating model ...
# Loading METEOR metric...
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /usr/share/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /usr/share/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Loading dataset ...
# Starting training ...
# Epoch 1 Training: 100%|██████████| 313/313 [01:24<00:00,  3.69it/s, loss=5.8320]
# Evaluating Epoch 1...
#    >>> [DEBUG] METEOR Calculated: 26.63%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [9735, 1818, 45, 0]}
# ratio: 0.9999999999999775
# --- Epoch 01 Complete (Time: 2m 15s) ---
# Training Loss: 5.9996 | Dev Loss: 6.0293
# ⭐️ Dev METEOR: 26.63%
# ⭐️ Dev BLEU-1: 21.97%
#  >>> SAVED: New best model found (BLEU-1: 21.97%)
#
#
# Epoch 2 Training: 100%|██████████| 313/313 [01:24<00:00,  3.69it/s, loss=4.7980]
# Evaluating Epoch 2...
#    >>> [DEBUG] METEOR Calculated: 27.01%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [11737, 2648, 253, 50]}
# ratio: 0.9999999999999775
# --- Epoch 02 Complete (Time: 2m 13s) ---
# Training Loss: 5.2553 | Dev Loss: 5.4068
# ⭐️ Dev METEOR: 27.01%
# ⭐️ Dev BLEU-1: 26.49%
#  >>> SAVED: New best model found (BLEU-1: 26.49%)
#
#
# Epoch 3 Training: 100%|██████████| 313/313 [01:25<00:00,  3.67it/s, loss=4.8264]
# Evaluating Epoch 3...
#    >>> [DEBUG] METEOR Calculated: 26.60%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12785, 2959, 452, 111]}
# ratio: 0.9999999999999775
# --- Epoch 03 Complete (Time: 2m 12s) ---
# Training Loss: 4.7269 | Dev Loss: 5.1805
# ⭐️ Dev METEOR: 26.60%
# ⭐️ Dev BLEU-1: 28.85%
#  >>> SAVED: New best model found (BLEU-1: 28.85%)
#
#
# Epoch 4 Training: 100%|██████████| 313/313 [01:25<00:00,  3.65it/s, loss=4.5480]
# Evaluating Epoch 4...
#    >>> [DEBUG] METEOR Calculated: 26.45%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12870, 3171, 591, 152]}
# ratio: 0.9999999999999775
# --- Epoch 04 Complete (Time: 2m 13s) ---
# Training Loss: 4.4369 | Dev Loss: 5.0701
# ⭐️ Dev METEOR: 26.45%
# ⭐️ Dev BLEU-1: 29.04%
#  >>> SAVED: New best model found (BLEU-1: 29.04%)
#
#
# Epoch 5 Training: 100%|██████████| 313/313 [01:25<00:00,  3.66it/s, loss=3.9936]
# Evaluating Epoch 5...
#    >>> [DEBUG] METEOR Calculated: 27.66%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12988, 3332, 675, 204]}
# ratio: 0.9999999999999775
# --- Epoch 05 Complete (Time: 2m 13s) ---
# Training Loss: 4.2077 | Dev Loss: 4.9920
# ⭐️ Dev METEOR: 27.66%
# ⭐️ Dev BLEU-1: 29.31%
#  >>> SAVED: New best model found (BLEU-1: 29.31%)
#
#
# Epoch 6 Training: 100%|██████████| 313/313 [01:25<00:00,  3.66it/s, loss=4.2030]
# Evaluating Epoch 6...
#    >>> [DEBUG] METEOR Calculated: 24.41%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12033, 3088, 755, 249]}
# ratio: 0.9999999999999775
# --- Epoch 06 Complete (Time: 2m 13s) ---
# Training Loss: 4.0165 | Dev Loss: 4.9899
# ⭐️ Dev METEOR: 24.41%
# ⭐️ Dev BLEU-1: 27.16%
#  >>> No improvement. Patience: 1/5
#
#
# Epoch 7 Training: 100%|██████████| 313/313 [01:25<00:00,  3.66it/s, loss=3.9981]
# Evaluating Epoch 7...
#    >>> [DEBUG] METEOR Calculated: 25.29%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12331, 3236, 806, 263]}
# ratio: 0.9999999999999775
# --- Epoch 07 Complete (Time: 2m 14s) ---
# Training Loss: 3.8448 | Dev Loss: 4.9760
# ⭐️ Dev METEOR: 25.29%
# ⭐️ Dev BLEU-1: 27.83%
#  >>> No improvement. Patience: 2/5
#
#
# Epoch 8 Training: 100%|██████████| 313/313 [01:24<00:00,  3.69it/s, loss=3.4201]
# Evaluating Epoch 8...
#    >>> [DEBUG] METEOR Calculated: 26.66%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12893, 3447, 813, 269]}
# ratio: 0.9999999999999775
# --- Epoch 08 Complete (Time: 2m 12s) ---
# Training Loss: 3.6883 | Dev Loss: 4.9968
# ⭐️ Dev METEOR: 26.66%
# ⭐️ Dev BLEU-1: 29.10%
#  >>> No improvement. Patience: 3/5
#
#
# Epoch 9 Training: 100%|██████████| 313/313 [01:24<00:00,  3.69it/s, loss=3.5222]
# Evaluating Epoch 9...
#    >>> [DEBUG] METEOR Calculated: 25.66%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12660, 3404, 842, 271]}
# ratio: 0.9999999999999775
# --- Epoch 09 Complete (Time: 2m 13s) ---
# Training Loss: 3.5452 | Dev Loss: 5.0401
# ⭐️ Dev METEOR: 25.66%
# ⭐️ Dev BLEU-1: 28.57%
#  >>> No improvement. Patience: 4/5
#
#
# Epoch 10 Training: 100%|█████████| 313/313 [01:25<00:00,  3.65it/s, loss=3.3028]
# Evaluating Epoch 10...
#    >>> [DEBUG] METEOR Calculated: 27.25%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13115, 3615, 921, 313]}
# ratio: 0.9999999999999775
# --- Epoch 10 Complete (Time: 2m 13s) ---
# Training Loss: 3.4073 | Dev Loss: 5.0367
# ⭐️ Dev METEOR: 27.25%
# ⭐️ Dev BLEU-1: 29.60%
#  >>> SAVED: New best model found (BLEU-1: 29.60%)
#
#
# Epoch 11 Training: 100%|█████████| 313/313 [01:26<00:00,  3.62it/s, loss=3.3196]
# Evaluating Epoch 11...
#    >>> [DEBUG] METEOR Calculated: 26.89%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13358, 3587, 932, 321]}
# ratio: 0.9999999999999775
# --- Epoch 11 Complete (Time: 2m 14s) ---
# Training Loss: 3.2781 | Dev Loss: 5.0799
# ⭐️ Dev METEOR: 26.89%
# ⭐️ Dev BLEU-1: 30.15%
#  >>> SAVED: New best model found (BLEU-1: 30.15%)
#
#
# Epoch 12 Training: 100%|█████████| 313/313 [01:25<00:00,  3.66it/s, loss=3.0564]
# Evaluating Epoch 12...
#    >>> [DEBUG] METEOR Calculated: 27.29%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13483, 3601, 910, 309]}
# ratio: 0.9999999999999775
# --- Epoch 12 Complete (Time: 2m 14s) ---
# Training Loss: 3.1569 | Dev Loss: 5.1474
# ⭐️ Dev METEOR: 27.29%
# ⭐️ Dev BLEU-1: 30.43%
#  >>> SAVED: New best model found (BLEU-1: 30.43%)
#
#
# Epoch 13 Training: 100%|█████████| 313/313 [01:25<00:00,  3.65it/s, loss=3.2020]
# Evaluating Epoch 13...
#    >>> [DEBUG] METEOR Calculated: 27.39%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13587, 3644, 973, 343]}
# ratio: 0.9999999999999775
# --- Epoch 13 Complete (Time: 2m 14s) ---
# Training Loss: 3.0427 | Dev Loss: 5.1783
# ⭐️ Dev METEOR: 27.39%
# ⭐️ Dev BLEU-1: 30.66%
#  >>> SAVED: New best model found (BLEU-1: 30.66%)
#
#
# Epoch 14 Training: 100%|█████████| 313/313 [01:25<00:00,  3.67it/s, loss=3.1065]
# Evaluating Epoch 14...
#    >>> [DEBUG] METEOR Calculated: 29.13%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13935, 3817, 949, 324]}
# ratio: 0.9999999999999775
# --- Epoch 14 Complete (Time: 2m 13s) ---
# Training Loss: 2.9340 | Dev Loss: 5.2179
# ⭐️ Dev METEOR: 29.13%
# ⭐️ Dev BLEU-1: 31.45%
#  >>> SAVED: New best model found (BLEU-1: 31.45%)
#
#
# Epoch 15 Training: 100%|█████████| 313/313 [01:25<00:00,  3.67it/s, loss=3.0610]
# Evaluating Epoch 15...
#    >>> [DEBUG] METEOR Calculated: 28.17%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13904, 3746, 978, 361]}
# ratio: 0.9999999999999775
# --- Epoch 15 Complete (Time: 2m 13s) ---
# Training Loss: 2.8327 | Dev Loss: 5.2826
# ⭐️ Dev METEOR: 28.17%
# ⭐️ Dev BLEU-1: 31.38%
#  >>> No improvement. Patience: 1/5
#
#
# Epoch 16 Training: 100%|█████████| 313/313 [01:25<00:00,  3.68it/s, loss=2.8736]
# Evaluating Epoch 16...
#    >>> [DEBUG] METEOR Calculated: 29.29%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [14119, 3865, 978, 339]}
# ratio: 0.9999999999999775
# --- Epoch 16 Complete (Time: 2m 13s) ---
# Training Loss: 2.7392 | Dev Loss: 5.3423
# ⭐️ Dev METEOR: 29.29%
# ⭐️ Dev BLEU-1: 31.86%
#  >>> SAVED: New best model found (BLEU-1: 31.86%)
#
#
# Epoch 17 Training: 100%|█████████| 313/313 [01:24<00:00,  3.71it/s, loss=2.6242]
# Evaluating Epoch 17...
#    >>> [DEBUG] METEOR Calculated: 29.80%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [14278, 3926, 1029, 367]}
# ratio: 0.9999999999999775
# --- Epoch 17 Complete (Time: 2m 12s) ---
# Training Loss: 2.6498 | Dev Loss: 5.4008
# ⭐️ Dev METEOR: 29.80%
# ⭐️ Dev BLEU-1: 32.22%
#  >>> SAVED: New best model found (BLEU-1: 32.22%)
#
#
# Epoch 18 Training: 100%|█████████| 313/313 [01:26<00:00,  3.63it/s, loss=2.7272]
# Evaluating Epoch 18...
#    >>> [DEBUG] METEOR Calculated: 28.57%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13953, 3776, 975, 337]}
# ratio: 0.9999999999999775
# --- Epoch 18 Complete (Time: 2m 14s) ---
# Training Loss: 2.5665 | Dev Loss: 5.4594
# ⭐️ Dev METEOR: 28.57%
# ⭐️ Dev BLEU-1: 31.49%
#  >>> No improvement. Patience: 1/5
#
#
# Epoch 19 Training: 100%|█████████| 313/313 [01:24<00:00,  3.69it/s, loss=2.6268]
# Evaluating Epoch 19...
#    >>> [DEBUG] METEOR Calculated: 29.53%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [14227, 3893, 1015, 359]}
# ratio: 0.9999999999999775
# --- Epoch 19 Complete (Time: 2m 12s) ---
# Training Loss: 2.4898 | Dev Loss: 5.5116
# ⭐️ Dev METEOR: 29.53%
# ⭐️ Dev BLEU-1: 32.11%
#  >>> No improvement. Patience: 2/5
#
#
# Epoch 20 Training: 100%|█████████| 313/313 [01:24<00:00,  3.71it/s, loss=2.4525]
# Evaluating Epoch 20...
#    >>> [DEBUG] METEOR Calculated: 29.81%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [14100, 3865, 958, 329]}
# ratio: 0.9999999999999775
# --- Epoch 20 Complete (Time: 2m 13s) ---
# Training Loss: 2.4143 | Dev Loss: 5.5623
# ⭐️ Dev METEOR: 29.81%
# ⭐️ Dev BLEU-1: 31.82%
#  >>> No improvement. Patience: 3/5
#
#
# Epoch 21 Training: 100%|█████████| 313/313 [01:24<00:00,  3.69it/s, loss=2.4833]
# Evaluating Epoch 21...
#    >>> [DEBUG] METEOR Calculated: 29.62%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [14146, 3819, 938, 319]}
# ratio: 0.9999999999999775
# --- Epoch 21 Complete (Time: 2m 12s) ---
# Training Loss: 2.3450 | Dev Loss: 5.6149
# ⭐️ Dev METEOR: 29.62%
# ⭐️ Dev BLEU-1: 31.92%
#  >>> No improvement. Patience: 4/5
#
#
# Epoch 22 Training: 100%|█████████| 313/313 [01:24<00:00,  3.68it/s, loss=2.4278]
# Evaluating Epoch 22...
#    >>> [DEBUG] METEOR Calculated: 28.84%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [14024, 3770, 971, 339]}
# ratio: 0.9999999999999775
# --- Epoch 22 Complete (Time: 2m 12s) ---
# Training Loss: 2.2782 | Dev Loss: 5.7097
# ⭐️ Dev METEOR: 28.84%
# ⭐️ Dev BLEU-1: 31.65%
#  >>> No improvement. Patience: 5/5
#
# *** EARLY STOPPING TRIGGERED ***
#
# Evaluating on test set using the BEST saved model ...
# Đã tải mô hình tốt nhất từ checkpoints/best_model.pt
#    >>> [DEBUG] METEOR Calculated: 29.86%
# {'testlen': 49513, 'reflen': 49513, 'guess': [49513, 47513, 45513, 43513], 'correct': [16181, 4584, 1223, 453]}
# ratio: 0.9999999999999799
#
# --- FINAL TEST RESULTS ---
# Test Loss: 5.2892
# METEOR: 29.86%
# BLEU-1: 32.68%
# BLEU-2: 17.76%
# BLEU-3: 9.46%
# BLEU-4: 5.45%
# ROUGE-L: 30.57%
